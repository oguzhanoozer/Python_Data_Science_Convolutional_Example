# %% [markdown]
# # DATA SCIENTIST
#  * Data Visualizaiton and Data Science Examples
#
# # Oğuzhan Özer
# <font color='red'> Content
#
# * [Matplotlib](#1)
# * [Pandas](#2)
# * [Tidy Data](#3)
# * [Concatenating Data](#4)
# * [Data Types](#5)
# * [Visual Exploratory Data Analysis](#6)
# * [Filtering Data Frames](#7)
# * [Indexing Data Frames](#8)

# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load in 

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

# Input data files are available in the "../input/" directory.
# For example, running this (by clicking run or pressing Shift+Enter) will list the files in the input directory

import os
print(os.listdir("../input"))


# Any results you write to the current directory are saved as output.
# Out:
# ['database.sqlite', 'Iris.csv']

# %%
data= pd.read_csv("../input/Iris.csv")
data.head()
# Out:
#    Id  SepalLengthCm     ...       PetalWidthCm      Species
# 0   1            5.1     ...                0.2  Iris-setosa
# 1   2            4.9     ...                0.2  Iris-setosa
# 2   3            4.7     ...                0.2  Iris-setosa
# 3   4            4.6     ...                0.2  Iris-setosa
# 4   5            5.0     ...                0.2  Iris-setosa
#
# [5 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
# Id               150 non-null int64
# SepalLengthCm    150 non-null float64
# SepalWidthCm     150 non-null float64
# PetalLengthCm    150 non-null float64
# PetalWidthCm     150 non-null float64
# Species          150 non-null object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.1+ KB

# %%
data.corr()
# Out:
#                      Id      ...       PetalWidthCm
# Id             1.000000      ...           0.899759
# SepalLengthCm  0.716676      ...           0.817954
# SepalWidthCm  -0.397729      ...          -0.356544
# PetalLengthCm  0.882747      ...           0.962757
# PetalWidthCm   0.899759      ...           1.000000
#
# [5 rows x 5 columns]

# %%
data.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %% [markdown]
# <a id="1"></a> <br>
# # MATPLOTLIB

# %%
data.SepalLengthCm.plot(kind = 'line', color = 'g',label = 'Speed',linewidth=2,alpha = 0.5,grid = True,linestyle = '-.')
data.PetalLengthCm.plot(color = 'r',label = 'Defense',linewidth=2, alpha = 0.5,grid = True,linestyle = '-')
plt.legend(loc='upper right')     # legend = puts label into plot
plt.xlabel('x axis')              # label = name of label
plt.ylabel('y axis')
plt.title('Line Plot')            # title = title of plot
plt.show()

# %%
# Histogram
# bins = number of bar in figure
data.SepalLengthCm.plot(kind = 'hist',bins = 70,figsize = (15,6))
plt.show()

# %% [markdown]
# <a id="2"></a> <br>
# # PANDAS

# %%
# 1 - Filtering Pandas data frame
x = data['SepalLengthCm']>7     # There are only 3 pokemons who have higher defense value than 200
data[x]
# Out:
#       Id  SepalLengthCm       ...        PetalWidthCm         Species
# 102  103            7.1       ...                 2.1  Iris-virginica
# 105  106            7.6       ...                 2.1  Iris-virginica
# 107  108            7.3       ...                 1.8  Iris-virginica
# 109  110            7.2       ...                 2.5  Iris-virginica
# 117  118            7.7       ...                 2.2  Iris-virginica
# 118  119            7.7       ...                 2.3  Iris-virginica
# 122  123            7.7       ...                 2.0  Iris-virginica
# 125  126            7.2       ...                 1.8  Iris-virginica
# 129  130            7.2       ...                 1.6  Iris-virginica
# 130  131            7.4       ...                 1.9  Iris-virginica
# 131  132            7.9       ...                 2.0  Iris-virginica
# 135  136            7.7       ...                 2.3  Iris-virginica
#
# [12 rows x 6 columns]

# %%
data[(data['SepalLengthCm']>7) & (data['SepalWidthCm']>2)]
# Out:
#       Id  SepalLengthCm       ...        PetalWidthCm         Species
# 102  103            7.1       ...                 2.1  Iris-virginica
# 105  106            7.6       ...                 2.1  Iris-virginica
# 107  108            7.3       ...                 1.8  Iris-virginica
# 109  110            7.2       ...                 2.5  Iris-virginica
# 117  118            7.7       ...                 2.2  Iris-virginica
# 118  119            7.7       ...                 2.3  Iris-virginica
# 122  123            7.7       ...                 2.0  Iris-virginica
# 125  126            7.2       ...                 1.8  Iris-virginica
# 129  130            7.2       ...                 1.6  Iris-virginica
# 130  131            7.4       ...                 1.9  Iris-virginica
# 131  132            7.9       ...                 2.0  Iris-virginica
# 135  136            7.7       ...                 2.3  Iris-virginica
#
# [12 rows x 6 columns]

# %%
data[np.logical_and(data['SepalLengthCm']>7 ,data['SepalWidthCm']>2)]
# Out:
#       Id  SepalLengthCm       ...        PetalWidthCm         Species
# 102  103            7.1       ...                 2.1  Iris-virginica
# 105  106            7.6       ...                 2.1  Iris-virginica
# 107  108            7.3       ...                 1.8  Iris-virginica
# 109  110            7.2       ...                 2.5  Iris-virginica
# 117  118            7.7       ...                 2.2  Iris-virginica
# 118  119            7.7       ...                 2.3  Iris-virginica
# 122  123            7.7       ...                 2.0  Iris-virginica
# 125  126            7.2       ...                 1.8  Iris-virginica
# 129  130            7.2       ...                 1.6  Iris-virginica
# 130  131            7.4       ...                 1.9  Iris-virginica
# 131  132            7.9       ...                 2.0  Iris-virginica
# 135  136            7.7       ...                 2.3  Iris-virginica
#
# [12 rows x 6 columns]

# %% [markdown]
# <a id="3"></a> <br>
# # TIDY DATA
#    * We tidy data with melt().

# %%
# Firstly I create new data from pokemons data to explain melt nore easily.
data_new = data.head()    # I only take 5 rows into new data
data_new
# Out:
#    Id  SepalLengthCm     ...       PetalWidthCm      Species
# 0   1            5.1     ...                0.2  Iris-setosa
# 1   2            4.9     ...                0.2  Iris-setosa
# 2   3            4.7     ...                0.2  Iris-setosa
# 3   4            4.6     ...                0.2  Iris-setosa
# 4   5            5.0     ...                0.2  Iris-setosa
#
# [5 rows x 6 columns]

# %%
# lets melt
# id_vars = what we do not wish to melt
# value_vars = what we want to melt
melted = pd.melt(frame=data_new,id_vars = 'Id', value_vars= ['PetalWidthCm','Species'])
melted
# Out:
#    Id      variable        value
# 0   1  PetalWidthCm          0.2
# 1   2  PetalWidthCm          0.2
# 2   3  PetalWidthCm          0.2
# 3   4  PetalWidthCm          0.2
# 4   5  PetalWidthCm          0.2
# 5   1       Species  Iris-setosa
# 6   2       Species  Iris-setosa
# 7   3       Species  Iris-setosa
# 8   4       Species  Iris-setosa
# 9   5       Species  Iris-setosa

# %% [markdown]
# <a id="4"></a> <br>
# # CONCATENATING DATA
#   * We can concatenate two dataframe

# %%
# Firstly lets create 2 data frame
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True) # axis = 0 : adds dataframes in row
conc_data_row
# Out:
#     Id  SepalLengthCm       ...        PetalWidthCm         Species
# 0    1            5.1       ...                 0.2     Iris-setosa
# 1    2            4.9       ...                 0.2     Iris-setosa
# 2    3            4.7       ...                 0.2     Iris-setosa
# 3    4            4.6       ...                 0.2     Iris-setosa
# 4    5            5.0       ...                 0.2     Iris-setosa
# 5  146            6.7       ...                 2.3  Iris-virginica
# 6  147            6.3       ...                 1.9  Iris-virginica
# 7  148            6.5       ...                 2.0  Iris-virginica
# 8  149            6.2       ...                 2.3  Iris-virginica
# 9  150            5.9       ...                 1.8  Iris-virginica
#
# [10 rows x 6 columns]

# %%
data1 = data['PetalLengthCm'].head()
data2= data['SepalLengthCm'].head()
conc_data_col = pd.concat([data1,data2],axis =1) # axis = 0 : adds dataframes in row
conc_data_col
# Out:
#    PetalLengthCm  SepalLengthCm
# 0            1.4            5.1
# 1            1.4            4.9
# 2            1.3            4.7
# 3            1.5            4.6
# 4            1.4            5.0

# %% [markdown]
# <a id="5"></a> <br>
# # DATA TYPES
#    * There are 5 basic data types: object(string),booleab, integer, float and categorical.
#    * We can make conversion data types like from str to categorical or from int to float
#    * Why is category important:
#
#         * make dataframe smaller in memory
#         * can be utilized for anlaysis especially for sklear(we will learn later)

# %%
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %%
data['SepalLengthCm'] = data['SepalLengthCm'].astype('int64')
data['PetalWidthCm'] = data['PetalWidthCm'].astype('int64')

# %%
data.dtypes
# Out:
# Id                 int64
# SepalLengthCm      int64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm       int64
# Species           object
# dtype: object

# %%
# Lets chech Type 2
data["PetalWidthCm"].value_counts(dropna =False)
# Out:
# 1    71
# 0    50
# 2    29
# Name: PetalWidthCm, dtype: int64

# %% [markdown]
# <a id="6"></a> <br>
# # VISUAL EXPLORATORY DATA ANALYSIS
# * Plot
# * Subplot
# * Histogram:
#         * bins: number of bins
#         * range(tuble): min and max values of bins
#         * normed(boolean): normalize or not
#         * cumulative(boolean): compute cumulative distribution

# %%
# Plotting all data 
data1 = data.loc[:,["PetalWidthCm","SepalLengthCm","SepalWidthCm"]]
data1.plot()
# it is confusing

# %%
# subplots
data1.plot(subplots = True)
plt.show()

# %%
data.describe()
# Out:
#                Id  SepalLengthCm      ...       PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000      ...          150.000000    150.000000
# mean    75.500000       5.386667      ...            3.758667      0.860000
# std     43.445368       0.841752      ...            1.764420      0.714472
# min      1.000000       4.000000      ...            1.000000      0.000000
# 25%     38.250000       5.000000      ...            1.600000      0.000000
# 50%     75.500000       5.000000      ...            4.350000      1.000000
# 75%    112.750000       6.000000      ...            5.100000      1.000000
# max    150.000000       7.000000      ...            6.900000      2.000000
#
# [8 rows x 5 columns]

# %% [markdown]
# <a id="7"></a> <br>
# # FILTERING DATA FRAMES
#    * Creating boolean series
#    * Combining filters
#    * Filtering column based others

# %%
# Creating boolean series
boolean = data.SepalWidthCm > 4
data[boolean]
# Out:
#     Id  SepalLengthCm     ...       PetalWidthCm      Species
# 15  16              5     ...                  0  Iris-setosa
# 32  33              5     ...                  0  Iris-setosa
# 33  34              5     ...                  0  Iris-setosa
#
# [3 rows x 6 columns]

# %%
first_filter = data.SepalWidthCm > 3
second_filter = data.PetalLengthCm > 3
data[first_filter & second_filter]
# Out:
#       Id  SepalLengthCm       ...         PetalWidthCm          Species
# 50    51              7       ...                    1  Iris-versicolor
# 51    52              6       ...                    1  Iris-versicolor
# 52    53              6       ...                    1  Iris-versicolor
# 56    57              6       ...                    1  Iris-versicolor
# 65    66              6       ...                    1  Iris-versicolor
# 70    71              5       ...                    1  Iris-versicolor
# 85    86              6       ...                    1  Iris-versicolor
# 86    87              6       ...                    1  Iris-versicolor
# 100  101              6       ...                    2   Iris-virginica
# 109  110              7       ...                    2   Iris-virginica
# 110  111              6       ...                    2   Iris-virginica
# 115  116              6       ...                    2   Iris-virginica
# 117  118              7       ...                    2   Iris-virginica
# 120  121              6       ...                    2   Iris-virginica
# 124  125              6       ...                    2   Iris-virginica
# 125  126              7       ...                    1   Iris-virginica
# 131  132              7       ...                    2   Iris-virginica
# 136  137              6       ...                    2   Iris-virginica
# 137  138              6       ...                    1   Iris-virginica
# 139  140              6       ...                    2   Iris-virginica
# 140  141              6       ...                    2   Iris-virginica
# 141  142              6       ...                    2   Iris-virginica
# 143  144              6       ...                    2   Iris-virginica
# 144  145              6       ...                    2   Iris-virginica
# 148  149              6       ...                    2   Iris-virginica
#
# [25 rows x 6 columns]

# %% [markdown]
# <a id="8"></a> <br>
# # INDEXING DATA FRAMES
#    * Indexing using square brackets
#    * Using column attribute and row label
#    * Using loc accessor
#    * Selecting only some columns

# %%
# read data
datax = pd.read_csv('../input/Iris.csv')
datax.head()
# Out:
#    Id  SepalLengthCm     ...       PetalWidthCm      Species
# 0   1            5.1     ...                0.2  Iris-setosa
# 1   2            4.9     ...                0.2  Iris-setosa
# 2   3            4.7     ...                0.2  Iris-setosa
# 3   4            4.6     ...                0.2  Iris-setosa
# 4   5            5.0     ...                0.2  Iris-setosa
#
# [5 rows x 6 columns]

# %%
datax.loc[1,["SepalWidthCm"]]
# Out:
# SepalWidthCm    3
# Name: 1, dtype: object

# %%
datax[["SepalLengthCm","SepalWidthCm"]]
# Out:
#      SepalLengthCm  SepalWidthCm
# 0              5.1           3.5
# 1              4.9           3.0
# 2              4.7           3.2
# 3              4.6           3.1
# 4              5.0           3.6
# 5              5.4           3.9
# 6              4.6           3.4
# 7              5.0           3.4
# 8              4.4           2.9
# 9              4.9           3.1
# 10             5.4           3.7
# 11             4.8           3.4
# 12             4.8           3.0
# 13             4.3           3.0
# 14             5.8           4.0
# 15             5.7           4.4
# 16             5.4           3.9
# 17             5.1           3.5
# 18             5.7           3.8
# 19             5.1           3.8
# 20             5.4           3.4
# 21             5.1           3.7
# 22             4.6           3.6
# 23             5.1           3.3
# 24             4.8           3.4
# 25             5.0           3.0
# 26             5.0           3.4
# 27             5.2           3.5
# 28             5.2           3.4
# 29             4.7           3.2
# ..             ...           ...
# 120            6.9           3.2
# 121            5.6           2.8
# 122            7.7           2.8
# 123            6.3           2.7
# 124            6.7           3.3
# 125            7.2           3.2
# 126            6.2           2.8
# 127            6.1           3.0
# 128            6.4           2.8
# 129            7.2           3.0
# 130            7.4           2.8
# 131            7.9           3.8
# 132            6.4           2.8
# 133            6.3           2.8
# 134            6.1           2.6
# 135            7.7           3.0
# 136            6.3           3.4
# 137            6.4           3.1
# 138            6.0           3.0
# 139            6.9           3.1
# 140            6.7           3.1
# 141            6.9           3.1
# 142            5.8           2.7
# 143            6.8           3.2
# 144            6.7           3.3
# 145            6.7           3.0
# 146            6.3           2.5
# 147            6.5           3.0
# 148            6.2           3.4
# 149            5.9           3.0
#
# [150 rows x 2 columns]
